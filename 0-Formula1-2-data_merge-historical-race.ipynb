# %%
# Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
"""
# Data Access
car_data = pd.read_csv("C:/Users/yunus/Downloads/Dataset-f1/ocean_data_challenge_F1_data/races_2024/car_data_2024.csv")
circuit_data = pd.read_csv("C:/Users/yunus/Downloads/Dataset-f1/ocean_data_challenge_F1_data/races_2024/circuit_2024.csv")
control_message_data = pd.read_csv("C:/Users/yunus/Downloads/Dataset-f1/ocean_data_challenge_F1_data/races_2024/control_message_2024.csv")
lap_data = pd.read_csv("C:/Users/yunus/Downloads/Dataset-f1/ocean_data_challenge_F1_data/races_2024/lap_2024.csv", low_memory=False)
position_data = pd.read_csv("C:/Users/yunus/Downloads/Dataset-f1/ocean_data_challenge_F1_data/races_2024/position_2024.csv")
result_data = pd.read_csv("C:/Users/yunus/Downloads/Dataset-f1/ocean_data_challenge_F1_data/races_2024/result_2024.csv")
session_status_data = pd.read_csv("C:/Users/yunus/Downloads/Dataset-f1/ocean_data_challenge_F1_data/races_2024/session_status_2024.csv")
track_status_data = pd.read_csv("C:/Users/yunus/Downloads/Dataset-f1/ocean_data_challenge_F1_data/races_2024/track_status_2024.csv")
weather_data = pd.read_csv("C:/Users/yunus/Downloads/Dataset-f1/ocean_data_challenge_F1_data/races_2024/weather_2024.csv")
"""

# %%
# Race Data Access
race_car_data = pd.read_csv("C:/Users/yunus/Downloads/Mexican GP Data Challenge Datasets/ocean_mexican_gp_data_challenge_datasets/mexican_gp_race_datasets_2018-2019-2021-2022-2023/car_data_mexico_grand_prix_2018-2019-2021-2022-2023.csv")
race_circuit_data = pd.read_csv("C:/Users/yunus/Downloads/Mexican GP Data Challenge Datasets/ocean_mexican_gp_data_challenge_datasets/mexican_gp_race_datasets_2018-2019-2021-2022-2023/circuit_mexico_grand_prix_2018-2019-2021-2022-2023.csv")
race_control_message_data = pd.read_csv("C:/Users/yunus/Downloads/Mexican GP Data Challenge Datasets/ocean_mexican_gp_data_challenge_datasets/mexican_gp_race_datasets_2018-2019-2021-2022-2023/control_message_mexico_grand_prix_2018-2019-2021-2022-2023.csv")
race_lap_data = pd.read_csv("C:/Users/yunus/Downloads/Mexican GP Data Challenge Datasets/ocean_mexican_gp_data_challenge_datasets/mexican_gp_race_datasets_2018-2019-2021-2022-2023/lap_mexico_grand_prix_2018-2019-2021-2022-2023.csv", low_memory=False)
race_position_data = pd.read_csv("C:/Users/yunus/Downloads/Mexican GP Data Challenge Datasets/ocean_mexican_gp_data_challenge_datasets/mexican_gp_race_datasets_2018-2019-2021-2022-2023/position_mexico_grand_prix_2018-2019-2021-2022-2023.csv")
race_result_data = pd.read_csv("C:/Users/yunus/Downloads/Mexican GP Data Challenge Datasets/ocean_mexican_gp_data_challenge_datasets/mexican_gp_race_datasets_2018-2019-2021-2022-2023/result_mexico_grand_prix_2018-2019-2021-2022-2023.csv")
race_session_status_data = pd.read_csv("C:/Users/yunus/Downloads/Mexican GP Data Challenge Datasets/ocean_mexican_gp_data_challenge_datasets/mexican_gp_race_datasets_2018-2019-2021-2022-2023/session_status_mexico_grand_prix_2018-2019-2021-2022-2023.csv")
race_track_status_data = pd.read_csv("C:/Users/yunus/Downloads/Mexican GP Data Challenge Datasets/ocean_mexican_gp_data_challenge_datasets/mexican_gp_race_datasets_2018-2019-2021-2022-2023/track_status_mexico_grand_prix_2018-2019-2021-2022-2023.csv")
race_weather_data = pd.read_csv("C:/Users/yunus/Downloads/Mexican GP Data Challenge Datasets/ocean_mexican_gp_data_challenge_datasets/mexican_gp_race_datasets_2018-2019-2021-2022-2023/weather_mexico_grand_prix_2018-2019-2021-2022-2023.csv")

# %%
# Data Merge
# 4. lap_data
# Extract days and hours
race_lap_data['Days'] = race_lap_data['Time'].apply(lambda x: int(x.split(' ')[0]))
race_lap_data['Hours'] = race_lap_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[0]))
race_lap_data['Minutes'] = race_lap_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[1]))

# View the updated DataFrame
print(race_lap_data)
# Out:
#       Year                    Time Driver  DriverNumber  \
# 0     2018  0 days 00:34:35.418000    GAS            10
# 1     2018  0 days 00:36:01.984000    GAS            10
# 2     2018  0 days 00:37:26.860000    GAS            10
# 3     2018  0 days 00:38:54.567000    GAS            10
# 4     2018  0 days 00:40:38.975000    GAS            10
# ...    ...                     ...    ...           ...
# 6532  2023  0 days 02:59:59.540000    PIA            81
# 6533  2023  0 days 03:01:22.902000    PIA            81
# 6534  2023  0 days 03:02:46.070000    PIA            81
# 6535  2023  0 days 03:04:09.050000    PIA            81
# 6536  2023  0 days 03:05:32.471000    PIA            81
#
#                      LapTime  LapNumber  Stint PitOutTime  \
# 0     0 days 00:01:36.516000        1.0    1.0        NaN
# 1     0 days 00:01:26.566000        2.0    1.0        NaN
# 2     0 days 00:01:24.876000        3.0    1.0        NaN
# ...

# %%
# Extract days and hours
race_weather_data['Days'] = race_weather_data['Time'].apply(lambda x: int(x.split(' ')[0]))
race_weather_data['Hours'] = race_weather_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[0]))
race_weather_data['Minutes'] = race_weather_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[1]))

# View the updated DataFrame
print(race_weather_data)
# Out:
#      Year                    Time  AirTemp  Humidity  Pressure  Rainfall  \
# 0    2018  0 days 00:00:04.381000     19.2      53.9     785.1     False
# 1    2018  0 days 00:01:04.395000     19.2      53.9     785.1     False
# 2    2018  0 days 00:02:04.409000     19.2      54.1     785.0     False
# 3    2018  0 days 00:03:04.425000     19.1      54.9     785.0     False
# 4    2018  0 days 00:04:04.438000     19.1      54.4     785.1     False
# ..    ...                     ...      ...       ...       ...       ...
# 784  2023  0 days 03:05:53.455000     26.2      19.0     778.5     False
# 785  2023  0 days 03:06:53.454000     26.1      19.0     778.7     False
# 786  2023  0 days 03:07:53.453000     26.2      19.0     778.7     False
# 787  2023  0 days 03:08:53.483000     26.1      19.0     778.7     False
# 788  2023  0 days 03:09:53.482000     26.0      19.0     778.5     False
#
#      TrackTemp  WindDirection  WindSpeed  Days  Hours  Minutes
# ...

# %%
# Remove duplicates in weather_data based on 'eventname' and 'hours'
race_weather_data1 = race_weather_data.drop_duplicates(subset=['Year', 'Hours', 'Minutes'])

# Now perform the left join
race_lap_data1 = pd.merge(race_lap_data, race_weather_data1, on=['Year', 'Hours', 'Minutes'], how='left')

# The number of rows in merged_df should now match df1

print(race_lap_data1)
# Out:
#       Year                  Time_x Driver  DriverNumber  \
# 0     2018  0 days 00:34:35.418000    GAS            10
# 1     2018  0 days 00:36:01.984000    GAS            10
# 2     2018  0 days 00:37:26.860000    GAS            10
# 3     2018  0 days 00:38:54.567000    GAS            10
# 4     2018  0 days 00:40:38.975000    GAS            10
# ...    ...                     ...    ...           ...
# 6532  2023  0 days 02:59:59.540000    PIA            81
# 6533  2023  0 days 03:01:22.902000    PIA            81
# 6534  2023  0 days 03:02:46.070000    PIA            81
# 6535  2023  0 days 03:04:09.050000    PIA            81
# 6536  2023  0 days 03:05:32.471000    PIA            81
#
#                      LapTime  LapNumber  Stint PitOutTime  \
# 0     0 days 00:01:36.516000        1.0    1.0        NaN
# 1     0 days 00:01:26.566000        2.0    1.0        NaN
# 2     0 days 00:01:24.876000        3.0    1.0        NaN
# ...

# %%
race_lap_data1.head(), race_lap_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6537 entries, 0 to 6536
# Data columns (total 44 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                6537 non-null   int64
#  1   Time_x              6537 non-null   object
#  2   Driver              6537 non-null   object
#  3   DriverNumber        6537 non-null   int64
#  4   LapTime             6500 non-null   object
#  5   LapNumber           6537 non-null   float64
#  6   Stint               6537 non-null   float64
#  7   PitOutTime          143 non-null    object
#  8   PitInTime           150 non-null    object
#  9   Sector1Time         6411 non-null   object
#  10  Sector2Time         6528 non-null   object
#  11  Sector3Time         6527 non-null   object
#  12  Sector1SessionTime  6397 non-null   object
#  13  Sector2SessionTime  6528 non-null   object
#  14  Sector3SessionTime  6527 non-null   object
# ...

# %%
# car_data
# Extract days and hours
race_car_data['Days'] = race_car_data['SessionTime'].apply(lambda x: int(x.split(' ')[0]))
race_car_data['Hours'] = race_car_data['SessionTime'].apply(lambda x: int(x.split(' ')[2].split(':')[0]))
race_car_data['Minutes'] = race_car_data['SessionTime'].apply(lambda x: int(x.split(' ')[2].split(':')[1]))

# View the updated DataFrame
print(race_car_data)
# Out:
#          Year DriverName                     Date    RPM  Speed  nGear  \
# 0        2018        VER  2018-10-28 19:12:58.809  11499      0      1
# 1        2018        VER  2018-10-28 19:12:59.049  11393      0      1
# 2        2018        VER  2018-10-28 19:12:59.289   9993      4      1
# 3        2018        VER  2018-10-28 19:12:59.529   8313     15      1
# 4        2018        VER  2018-10-28 19:12:59.769   6773     22      1
# ...       ...        ...                      ...    ...    ...    ...
# 2302767  2023        PER  2023-10-29 20:05:00.931   6950     80      2
# 2302768  2023        PER  2023-10-29 20:05:01.131   7048     80      2
# 2302769  2023        PER  2023-10-29 20:05:01.371   6958     80      2
# 2302770  2023        PER  2023-10-29 20:05:01.531   7068     80      2
# 2302771  2023        PER  2023-10-29 20:05:01.811   6981     80      2
#
#          Throttle  Brake  DRS Source                    Time  \
# ...

# %%
race_car_data.head(), race_car_data.info(), race_car_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2302772 entries, 0 to 2302771
# Data columns (total 15 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Year         int64
#  1   DriverName   object
#  2   Date         object
#  3   RPM          int64
#  4   Speed        int64
#  5   nGear        int64
#  6   Throttle     int64
#  7   Brake        bool
#  8   DRS          int64
#  9   Source       object
#  10  Time         object
#  11  SessionTime  object
#  12  Days         int64
#  13  Hours        int64
#  14  Minutes      int64
# dtypes: bool(1), int64(9), object(5)
# memory usage: 248.2+ MB
# (   Year DriverName                     Date    RPM  Speed  nGear  Throttle  \
#  0  2018        VER  2018-10-28 19:12:58.809  11499      0      1        13
#  1  2018        VER  2018-10-28 19:12:59.049  11393      0      1        13
#  2  2018        VER  2018-10-28 19:12:59.289   9993      4      1        14
# ...

# %%
race_car_data.describe(include='object')
# Out:
#        DriverName                     Date   Source                    Time  \
# count     2302772                  2302772  2302772                 2302772
# unique         33                   124299        1                  123713
# top           GAS  2018-10-28 19:12:58.809      car  0 days 00:05:29.809000
# freq       123729                       20  2302772                      39
#
#                    SessionTime
# count                  2302772
# unique                  123226
# top     0 days 01:21:45.357000
# freq                        40

# %%
# Remove duplicates in weather_data based on 'eventname' and 'hours'
race_car_data1 = race_car_data.drop_duplicates(subset=['Year', 'DriverName', 'Hours', 'Minutes'])

# %%
race_car_data1.rename(columns={'DriverName': 'Driver'}, inplace=True)
# Out:
# C:\Users\yunus\AppData\Local\Temp\ipykernel_3112\1045484187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   race_car_data1.rename(columns={'DriverName': 'Driver'}, inplace=True)

# %%
race_car_data1.head(), race_car_data1.info(), race_car_data1.describe(), race_car_data1.describe(include='object')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9746 entries, 0 to 2302764
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         9746 non-null   int64
#  1   Driver       9746 non-null   object
#  2   Date         9746 non-null   object
#  3   RPM          9746 non-null   int64
#  4   Speed        9746 non-null   int64
#  5   nGear        9746 non-null   int64
#  6   Throttle     9746 non-null   int64
#  7   Brake        9746 non-null   bool
#  8   DRS          9746 non-null   int64
#  9   Source       9746 non-null   object
#  10  Time         9746 non-null   object
#  11  SessionTime  9746 non-null   object
#  12  Days         9746 non-null   int64
#  13  Hours        9746 non-null   int64
#  14  Minutes      9746 non-null   int64
# dtypes: bool(1), int64(9), object(5)
# memory usage: 1.1+ MB
# (     Year Driver                     Date    RPM  Speed  nGear  Throttle  \
# ...

# %%
# Remove duplicates in weather_data based on 'eventname' and 'hours'
# car_data1 = car_data.drop_duplicates(subset=['EventName', 'DriverName', 'Hours', 'Minutes'])

# Now perform the left join
race_lap_data2 = pd.merge(race_lap_data1, race_car_data1, on=['Year', 'Driver', 'Hours', 'Minutes'], how='left')

# The number of rows in merged_df should now match df1

print(race_lap_data2)
# Out:
#       Year                  Time_x Driver  DriverNumber  \
# 0     2018  0 days 00:34:35.418000    GAS            10
# 1     2018  0 days 00:36:01.984000    GAS            10
# 2     2018  0 days 00:37:26.860000    GAS            10
# 3     2018  0 days 00:38:54.567000    GAS            10
# 4     2018  0 days 00:40:38.975000    GAS            10
# ...    ...                     ...    ...           ...
# 6532  2023  0 days 02:59:59.540000    PIA            81
# 6533  2023  0 days 03:01:22.902000    PIA            81
# 6534  2023  0 days 03:02:46.070000    PIA            81
# 6535  2023  0 days 03:04:09.050000    PIA            81
# 6536  2023  0 days 03:05:32.471000    PIA            81
#
#                      LapTime  LapNumber  Stint PitOutTime  \
# 0     0 days 00:01:36.516000        1.0    1.0        NaN
# 1     0 days 00:01:26.566000        2.0    1.0        NaN
# 2     0 days 00:01:24.876000        3.0    1.0        NaN
# ...

# %%
race_lap_data2.head(), race_lap_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6537 entries, 0 to 6536
# Data columns (total 55 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                6537 non-null   int64
#  1   Time_x              6537 non-null   object
#  2   Driver              6537 non-null   object
#  3   DriverNumber        6537 non-null   int64
#  4   LapTime             6500 non-null   object
#  5   LapNumber           6537 non-null   float64
#  6   Stint               6537 non-null   float64
#  7   PitOutTime          143 non-null    object
#  8   PitInTime           150 non-null    object
#  9   Sector1Time         6411 non-null   object
#  10  Sector2Time         6528 non-null   object
#  11  Sector3Time         6527 non-null   object
#  12  Sector1SessionTime  6397 non-null   object
#  13  Sector2SessionTime  6528 non-null   object
#  14  Sector3SessionTime  6527 non-null   object
# ...

# %%
# Data Merge
# 5. position
race_position_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3607720 entries, 0 to 3607719
# Data columns (total 10 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Year         int64
#  1   DriverName   object
#  2   Date         object
#  3   Status       object
#  4   X            int64
#  5   Y            int64
#  6   Z            int64
#  7   Source       object
#  8   Time         object
#  9   SessionTime  object
# dtypes: int64(4), object(6)
# memory usage: 275.2+ MB

# %%
race_position_data.head(), race_position_data.tail()
# Out:
# (   Year DriverName                     Date    Status  X  Y  Z Source  \
#  0  2018        VER  2018-10-28 18:40:01.328  OffTrack  0  0  0    pos
#  1  2018        VER  2018-10-28 18:40:01.628  OffTrack  0  0  0    pos
#  2  2018        VER  2018-10-28 18:40:01.928  OffTrack  0  0  0    pos
#  3  2018        VER  2018-10-28 18:40:02.228  OffTrack  0  0  0    pos
#  4  2018        VER  2018-10-28 18:40:02.528  OffTrack  0  0  0    pos
#
#                       Time             SessionTime
#  0  0 days 00:00:01.226000  0 days 00:00:01.226000
#  1  0 days 00:00:01.526000  0 days 00:00:01.526000
#  2  0 days 00:00:01.826000  0 days 00:00:01.826000
#  3  0 days 00:00:02.126000  0 days 00:00:02.126000
#  4  0 days 00:00:02.426000  0 days 00:00:02.426000  ,
#           Year DriverName                     Date   Status    X    Y      Z  \
#  3607715  2023        PER  2023-10-29 22:10:44.652  OnTrack  198  944  22266
# ...

# %%
race_position_data.rename(columns={'DriverName': 'Driver'}, inplace=True)

# %%
# position_data
# Extract days and hours
race_position_data['Days'] = race_position_data['Time'].apply(lambda x: int(x.split(' ')[0]))
race_position_data['Hours'] = race_position_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[0]))
race_position_data['Minutes'] = race_position_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[1]))

# View the updated DataFrame
print(race_position_data)
# Out:
#          Year Driver                     Date    Status    X    Y      Z  \
# 0        2018    VER  2018-10-28 18:40:01.328  OffTrack    0    0      0
# 1        2018    VER  2018-10-28 18:40:01.628  OffTrack    0    0      0
# 2        2018    VER  2018-10-28 18:40:01.928  OffTrack    0    0      0
# 3        2018    VER  2018-10-28 18:40:02.228  OffTrack    0    0      0
# 4        2018    VER  2018-10-28 18:40:02.528  OffTrack    0    0      0
# ...       ...    ...                      ...       ...  ...  ...    ...
# 3607715  2023    PER  2023-10-29 22:10:44.652   OnTrack  198  944  22266
# 3607716  2023    PER  2023-10-29 22:10:44.812   OnTrack  198  944  22266
# 3607717  2023    PER  2023-10-29 22:10:45.132   OnTrack  198  944  22266
# 3607718  2023    PER  2023-10-29 22:10:45.311   OnTrack  198  944  22266
# 3607719  2023    PER  2023-10-29 22:10:45.511   OnTrack  198  944  22266
#
#         Source                    Time             SessionTime  Days  Hours  \
# ...

# %%
# Remove duplicates in position_data based on 'eventname' and 'hours'
race_position_data1 = race_position_data.drop_duplicates(subset=['Year', 'Driver', 'Hours', 'Minutes'])

# Now perform the left join
race_lap_data3 = pd.merge(race_lap_data2, race_position_data1, on=['Year', 'Driver', 'Hours', 'Minutes'], how='left', suffixes=('_left', '_right'))

# The number of rows in merged_df should now match df1

print(race_lap_data3)
# Out:
#       Year                  Time_x Driver  DriverNumber  \
# 0     2018  0 days 00:34:35.418000    GAS            10
# 1     2018  0 days 00:36:01.984000    GAS            10
# 2     2018  0 days 00:37:26.860000    GAS            10
# 3     2018  0 days 00:38:54.567000    GAS            10
# 4     2018  0 days 00:40:38.975000    GAS            10
# ...    ...                     ...    ...           ...
# 6532  2023  0 days 02:59:59.540000    PIA            81
# 6533  2023  0 days 03:01:22.902000    PIA            81
# 6534  2023  0 days 03:02:46.070000    PIA            81
# 6535  2023  0 days 03:04:09.050000    PIA            81
# 6536  2023  0 days 03:05:32.471000    PIA            81
#
#                      LapTime  LapNumber  Stint PitOutTime  \
# 0     0 days 00:01:36.516000        1.0    1.0        NaN
# 1     0 days 00:01:26.566000        2.0    1.0        NaN
# 2     0 days 00:01:24.876000        3.0    1.0        NaN
# ...

# %%
race_lap_data3.head(), race_lap_data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6537 entries, 0 to 6536
# Data columns (total 64 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                6537 non-null   int64
#  1   Time_x              6537 non-null   object
#  2   Driver              6537 non-null   object
#  3   DriverNumber        6537 non-null   int64
#  4   LapTime             6500 non-null   object
#  5   LapNumber           6537 non-null   float64
#  6   Stint               6537 non-null   float64
#  7   PitOutTime          143 non-null    object
#  8   PitInTime           150 non-null    object
#  9   Sector1Time         6411 non-null   object
#  10  Sector2Time         6528 non-null   object
#  11  Sector3Time         6527 non-null   object
#  12  Sector1SessionTime  6397 non-null   object
#  13  Sector2SessionTime  6528 non-null   object
#  14  Sector3SessionTime  6527 non-null   object
# ...

# %%
# Data Merge
# 6. result_data

# %%
race_result_data.info(), race_result_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                100 non-null    int64
#  1   DriverNumber        100 non-null    int64
#  2   BroadcastName       100 non-null    object
#  3   Abbreviation        100 non-null    object
#  4   DriverId            100 non-null    object
#  5   TeamName            100 non-null    object
#  6   TeamColor           100 non-null    object
#  7   TeamId              100 non-null    object
#  8   FirstName           100 non-null    object
#  9   LastName            100 non-null    object
#  10  FullName            100 non-null    object
#  11  HeadshotUrl         78 non-null     object
#  12  CountryCode         40 non-null     object
#  13  Position            100 non-null    float64
#  14  ClassifiedPosition  100 non-null    object
# ...

# %%
race_result_data.rename(columns={'Abbreviation': 'Driver'}, inplace=True)

# %%
# Remove duplicates in result_data based on 'eventname' and 'hours'
# result_data1 = result_data.drop_duplicates(subset=['EventName', 'Hours', 'Minutes'])

# Now perform the left join
race_lap_data4 = pd.merge(race_lap_data3, race_result_data, on=['Year', 'Driver'], how='left', suffixes=('_left', '_right'))

# The number of rows in merged_df should now match df1

print(race_lap_data4)
# Out:
#       Year                  Time_x Driver  DriverNumber_left  \
# 0     2018  0 days 00:34:35.418000    GAS                 10
# 1     2018  0 days 00:36:01.984000    GAS                 10
# 2     2018  0 days 00:37:26.860000    GAS                 10
# 3     2018  0 days 00:38:54.567000    GAS                 10
# 4     2018  0 days 00:40:38.975000    GAS                 10
# ...    ...                     ...    ...                ...
# 6532  2023  0 days 02:59:59.540000    PIA                 81
# 6533  2023  0 days 03:01:22.902000    PIA                 81
# 6534  2023  0 days 03:02:46.070000    PIA                 81
# 6535  2023  0 days 03:04:09.050000    PIA                 81
# 6536  2023  0 days 03:05:32.471000    PIA                 81
#
#                      LapTime  LapNumber  Stint PitOutTime  \
# 0     0 days 00:01:36.516000        1.0    1.0        NaN
# 1     0 days 00:01:26.566000        2.0    1.0        NaN
# ...

# %%
race_lap_data4.info(), race_lap_data4.describe(), race_lap_data4.describe(include='object')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6537 entries, 0 to 6536
# Data columns (total 84 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                6537 non-null   int64
#  1   Time_x              6537 non-null   object
#  2   Driver              6537 non-null   object
#  3   DriverNumber_left   6537 non-null   int64
#  4   LapTime             6500 non-null   object
#  5   LapNumber           6537 non-null   float64
#  6   Stint               6537 non-null   float64
#  7   PitOutTime          143 non-null    object
#  8   PitInTime           150 non-null    object
#  9   Sector1Time         6411 non-null   object
#  10  Sector2Time         6528 non-null   object
#  11  Sector3Time         6527 non-null   object
#  12  Sector1SessionTime  6397 non-null   object
#  13  Sector2SessionTime  6528 non-null   object
#  14  Sector3SessionTime  6527 non-null   object
# ...

# %%
race_lap_data4['Date_left']
# Out:
# 0       2018-10-28 19:14:00.290
# 1       2018-10-28 19:16:00.212
# 2       2018-10-28 19:17:00.293
# 3       2018-10-28 19:18:00.133
# 4       2018-10-28 19:20:00.175
#                  ...
# 6532    2023-10-29 22:00:00.233
# 6533    2023-10-29 22:02:00.354
# 6534    2023-10-29 22:03:00.234
# 6535    2023-10-29 22:05:00.274
# 6536    2023-10-29 22:06:00.234
# Name: Date_left, Length: 6537, dtype: object

# %%
race_lap_data4['Date_right']
# Out:
# 0       2018-10-28 19:14:00.358
# 1       2018-10-28 19:16:00.359
# 2       2018-10-28 19:17:00.360
# 3       2018-10-28 19:18:00.362
# 4       2018-10-28 19:20:00.363
#                  ...
# 6532    2023-10-29 22:00:00.492
# 6533    2023-10-29 22:02:00.271
# 6534    2023-10-29 22:03:00.232
# 6535    2023-10-29 22:05:00.252
# 6536    2023-10-29 22:06:00.212
# Name: Date_right, Length: 6537, dtype: object

# %%
# Data Merge
# 3. control_message (Cancelled due to similar data from track_status)
# print(control_message_data)

# %%
# Data Merge
# 7. track_status
print(race_track_status_data)
# Out:
#     Year                    Time  Status      Message
# 0   2018  0 days 00:05:20.880000       1     AllClear
# 1   2018  0 days 00:38:30.932000       2       Yellow
# 2   2018  0 days 00:38:48.936000       1     AllClear
# 3   2018  0 days 00:38:53.651000       2       Yellow
# 4   2018  0 days 00:38:58.567000       6  VSCDeployed
# 5   2018  0 days 00:39:55.469000       7    VSCEnding
# 6   2018  0 days 00:40:06.874000       1     AllClear
# 7   2018  0 days 01:14:15.429000       2       Yellow
# 8   2018  0 days 01:14:41.480000       6  VSCDeployed
# 9   2018  0 days 01:17:37.957000       7    VSCEnding
# 10  2018  0 days 01:17:50.261000       1     AllClear
# 11  2018  0 days 01:57:58.372000       2       Yellow
# 12  2018  0 days 01:58:13.123000       6  VSCDeployed
# 13  2018  0 days 02:00:43.030000       7    VSCEnding
# 14  2018  0 days 02:00:57.466000       1     AllClear
# 15  2019         0 days 00:00:00       1     AllClear
# ...

# %%
race_track_status_data.head(20)
# Out:
#     Year                    Time  Status      Message
# 0   2018  0 days 00:05:20.880000       1     AllClear
# 1   2018  0 days 00:38:30.932000       2       Yellow
# 2   2018  0 days 00:38:48.936000       1     AllClear
# 3   2018  0 days 00:38:53.651000       2       Yellow
# 4   2018  0 days 00:38:58.567000       6  VSCDeployed
# 5   2018  0 days 00:39:55.469000       7    VSCEnding
# 6   2018  0 days 00:40:06.874000       1     AllClear
# 7   2018  0 days 01:14:15.429000       2       Yellow
# 8   2018  0 days 01:14:41.480000       6  VSCDeployed
# 9   2018  0 days 01:17:37.957000       7    VSCEnding
# 10  2018  0 days 01:17:50.261000       1     AllClear
# 11  2018  0 days 01:57:58.372000       2       Yellow
# 12  2018  0 days 01:58:13.123000       6  VSCDeployed
# 13  2018  0 days 02:00:43.030000       7    VSCEnding
# 14  2018  0 days 02:00:57.466000       1     AllClear
# 15  2019         0 days 00:00:00       1     AllClear
# ...

# %%
# track_status_data
# Extract days and hours
race_track_status_data['Days'] = race_track_status_data['Time'].apply(lambda x: int(x.split(' ')[0]))
race_track_status_data['Hours'] = race_track_status_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[0]))
race_track_status_data['Minutes'] = race_track_status_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[1]))

# View the updated DataFrame
print(race_track_status_data)
# Out:
#     Year                    Time  Status      Message  Days  Hours  Minutes
# 0   2018  0 days 00:05:20.880000       1     AllClear     0      0        5
# 1   2018  0 days 00:38:30.932000       2       Yellow     0      0       38
# 2   2018  0 days 00:38:48.936000       1     AllClear     0      0       38
# 3   2018  0 days 00:38:53.651000       2       Yellow     0      0       38
# 4   2018  0 days 00:38:58.567000       6  VSCDeployed     0      0       38
# 5   2018  0 days 00:39:55.469000       7    VSCEnding     0      0       39
# 6   2018  0 days 00:40:06.874000       1     AllClear     0      0       40
# 7   2018  0 days 01:14:15.429000       2       Yellow     0      1       14
# 8   2018  0 days 01:14:41.480000       6  VSCDeployed     0      1       14
# 9   2018  0 days 01:17:37.957000       7    VSCEnding     0      1       17
# 10  2018  0 days 01:17:50.261000       1     AllClear     0      1       17
# ...

# %%
# Remove duplicates in track_status_data based on 'eventname' and 'hours'
race_track_status_data1 = race_track_status_data.drop_duplicates(subset=['Year', 'Hours', 'Minutes'])

# Now perform the left join
race_lap_data5 = pd.merge(race_lap_data4, race_track_status_data1, on=['Year', 'Hours', 'Minutes'], how='left', suffixes=('_left2', '_right2'))

# The number of rows in merged_df should now match df1

print(race_lap_data5)
# Out:
#       Year                  Time_x Driver  DriverNumber_left  \
# 0     2018  0 days 00:34:35.418000    GAS                 10
# 1     2018  0 days 00:36:01.984000    GAS                 10
# 2     2018  0 days 00:37:26.860000    GAS                 10
# 3     2018  0 days 00:38:54.567000    GAS                 10
# 4     2018  0 days 00:40:38.975000    GAS                 10
# ...    ...                     ...    ...                ...
# 6532  2023  0 days 02:59:59.540000    PIA                 81
# 6533  2023  0 days 03:01:22.902000    PIA                 81
# 6534  2023  0 days 03:02:46.070000    PIA                 81
# 6535  2023  0 days 03:04:09.050000    PIA                 81
# 6536  2023  0 days 03:05:32.471000    PIA                 81
#
#                      LapTime  LapNumber  Stint PitOutTime  \
# 0     0 days 00:01:36.516000        1.0    1.0        NaN
# 1     0 days 00:01:26.566000        2.0    1.0        NaN
# ...

# %%
race_lap_data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6537 entries, 0 to 6536
# Data columns (total 88 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                6537 non-null   int64
#  1   Time_x              6537 non-null   object
#  2   Driver              6537 non-null   object
#  3   DriverNumber_left   6537 non-null   int64
#  4   LapTime             6500 non-null   object
#  5   LapNumber           6537 non-null   float64
#  6   Stint               6537 non-null   float64
#  7   PitOutTime          143 non-null    object
#  8   PitInTime           150 non-null    object
#  9   Sector1Time         6411 non-null   object
#  10  Sector2Time         6528 non-null   object
#  11  Sector3Time         6527 non-null   object
#  12  Sector1SessionTime  6397 non-null   object
#  13  Sector2SessionTime  6528 non-null   object
#  14  Sector3SessionTime  6527 non-null   object
# ...

# %%
# Data Merge
# 7. session_status_data
print(race_session_status_data)
# Out:
#     Year                    Time     Status
# 0   2018  0 days 00:00:05.668000   Inactive
# 1   2018  0 days 00:32:58.703000    Started
# 2   2018  0 days 02:11:27.752000   Finished
# 3   2018  0 days 02:17:35.869000  Finalised
# 4   2018  0 days 02:18:49.277000       Ends
# 5   2019  0 days 00:00:06.837000   Inactive
# 6   2019  0 days 00:33:01.144000    Started
# 7   2019  0 days 02:09:50.250000   Finished
# 8   2019  0 days 02:12:12.407000  Finalised
# 9   2019  0 days 02:16:25.214000       Ends
# 10  2021  0 days 00:00:06.232000   Inactive
# 11  2021  0 days 01:02:03.441000    Started
# 12  2021  0 days 02:40:42.728000   Finished
# 13  2021  0 days 02:43:58.701000  Finalised
# 14  2021  0 days 02:43:58.701000       Ends
# 15  2022  0 days 00:00:05.422000   Inactive
# 16  2022  0 days 01:02:06.736000    Started
# 17  2022  0 days 02:40:43.657000   Finished
# 18  2022  0 days 02:44:40.899000  Finalised
# 19  2022  0 days 02:44:40.899000       Ends
# ...

# %%
# session_status_data
# Extract days and hours
race_session_status_data['Days'] = race_session_status_data['Time'].apply(lambda x: int(x.split(' ')[0]))
race_session_status_data['Hours'] = race_session_status_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[0]))
race_session_status_data['Minutes'] = race_session_status_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[1]))

# View the updated DataFrame
print(race_session_status_data)
# Out:
#     Year                    Time     Status  Days  Hours  Minutes
# 0   2018  0 days 00:00:05.668000   Inactive     0      0        0
# 1   2018  0 days 00:32:58.703000    Started     0      0       32
# 2   2018  0 days 02:11:27.752000   Finished     0      2       11
# 3   2018  0 days 02:17:35.869000  Finalised     0      2       17
# 4   2018  0 days 02:18:49.277000       Ends     0      2       18
# 5   2019  0 days 00:00:06.837000   Inactive     0      0        0
# 6   2019  0 days 00:33:01.144000    Started     0      0       33
# 7   2019  0 days 02:09:50.250000   Finished     0      2        9
# 8   2019  0 days 02:12:12.407000  Finalised     0      2       12
# 9   2019  0 days 02:16:25.214000       Ends     0      2       16
# 10  2021  0 days 00:00:06.232000   Inactive     0      0        0
# 11  2021  0 days 01:02:03.441000    Started     0      1        2
# 12  2021  0 days 02:40:42.728000   Finished     0      2       40
# ...

# %%
# Remove duplicates in track_status_data based on 'eventname' and 'hours'
race_session_status_data1 = race_session_status_data.drop_duplicates(subset=['Year', 'Hours', 'Minutes'])

# Now perform the left join
race_lap_data6 = pd.merge(race_lap_data5, race_session_status_data1, on=['Year', 'Hours', 'Minutes'], how='left', suffixes=('_left3', '_right3'))

# The number of rows in merged_df should now match df1

print(race_lap_data6)
# Out:
#       Year                  Time_x Driver  DriverNumber_left  \
# 0     2018  0 days 00:34:35.418000    GAS                 10
# 1     2018  0 days 00:36:01.984000    GAS                 10
# 2     2018  0 days 00:37:26.860000    GAS                 10
# 3     2018  0 days 00:38:54.567000    GAS                 10
# 4     2018  0 days 00:40:38.975000    GAS                 10
# ...    ...                     ...    ...                ...
# 6532  2023  0 days 02:59:59.540000    PIA                 81
# 6533  2023  0 days 03:01:22.902000    PIA                 81
# 6534  2023  0 days 03:02:46.070000    PIA                 81
# 6535  2023  0 days 03:04:09.050000    PIA                 81
# 6536  2023  0 days 03:05:32.471000    PIA                 81
#
#                      LapTime  LapNumber  Stint PitOutTime  \
# 0     0 days 00:01:36.516000        1.0    1.0        NaN
# 1     0 days 00:01:26.566000        2.0    1.0        NaN
# ...

# %%
race_lap_data6.info(), race_lap_data6.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6537 entries, 0 to 6536
# Data columns (total 91 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                6537 non-null   int64
#  1   Time_x              6537 non-null   object
#  2   Driver              6537 non-null   object
#  3   DriverNumber_left   6537 non-null   int64
#  4   LapTime             6500 non-null   object
#  5   LapNumber           6537 non-null   float64
#  6   Stint               6537 non-null   float64
#  7   PitOutTime          143 non-null    object
#  8   PitInTime           150 non-null    object
#  9   Sector1Time         6411 non-null   object
#  10  Sector2Time         6528 non-null   object
#  11  Sector3Time         6527 non-null   object
#  12  Sector1SessionTime  6397 non-null   object
#  13  Sector2SessionTime  6528 non-null   object
#  14  Sector3SessionTime  6527 non-null   object
# ...

# %%
# Save DataFrame to CSV
race_lap_data6.to_csv('race_all_data.csv', index=False)

# %%
"""
# 2. circuit_data
# Extract days and hours
circuit_data['Days'] = circuit_data['Time'].apply(lambda x: int(x.split(' ')[0]))
circuit_data['Hours'] = circuit_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[0]))
circuit_data['Minutes'] = circuit_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[1]))

# View the updated DataFrame
print(circuit_data)
"""

# %%
"""
# 3. control_message_data
# Extract days and hours
control_message_data['Days'] = control_message_data['Time'].apply(lambda x: int(x.split(' ')[0]))
control_message_data['Hours'] = control_message_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[0]))
control_message_data['Minutes'] = control_message_data['Time'].apply(lambda x: int(x.split(' ')[2].split(':')[1]))

# View the updated DataFrame
print(control_message_data)
"""
