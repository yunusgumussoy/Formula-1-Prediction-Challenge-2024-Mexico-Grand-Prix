# %%
# Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
race_all_data = pd.read_csv("C:/Users/yunus/Downloads/race_all_data.csv")
all_data = pd.read_csv("C:/Users/yunus/Downloads/all_data.csv", low_memory=False)

# %%
race_all_data.info(), all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6537 entries, 0 to 6536
# Data columns (total 91 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                6537 non-null   int64
#  1   Time_x              6537 non-null   object
#  2   Driver              6537 non-null   object
#  3   DriverNumber_left   6537 non-null   int64
#  4   LapTime             6500 non-null   object
#  5   LapNumber           6537 non-null   float64
#  6   Stint               6537 non-null   float64
#  7   PitOutTime          143 non-null    object
#  8   PitInTime           150 non-null    object
#  9   Sector1Time         6411 non-null   object
#  10  Sector2Time         6528 non-null   object
#  11  Sector3Time         6527 non-null   object
#  12  Sector1SessionTime  6397 non-null   object
#  13  Sector2SessionTime  6528 non-null   object
#  14  Sector3SessionTime  6527 non-null   object
# ...

# %%
race_all_data.insert(loc=0, column='EventName', value='Mexican Grand Prix')

# %%
all_data.insert(loc=1, column='Year', value=2024)

# %%
# race_all_data['EventName'] = 'Mexican Grand Prix'

# %%
# all_data['Year'] = 2024

# %%
race_all_data.info(), all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6537 entries, 0 to 6536
# Data columns (total 92 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EventName           6537 non-null   object
#  1   Year                6537 non-null   int64
#  2   Time_x              6537 non-null   object
#  3   Driver              6537 non-null   object
#  4   DriverNumber_left   6537 non-null   int64
#  5   LapTime             6500 non-null   object
#  6   LapNumber           6537 non-null   float64
#  7   Stint               6537 non-null   float64
#  8   PitOutTime          143 non-null    object
#  9   PitInTime           150 non-null    object
#  10  Sector1Time         6411 non-null   object
#  11  Sector2Time         6528 non-null   object
#  12  Sector3Time         6527 non-null   object
#  13  Sector1SessionTime  6397 non-null   object
#  14  Sector2SessionTime  6528 non-null   object
# ...

# %%
race_all_data.head(), all_data.head()
# Out:
# (            EventName  Year                  Time_x Driver  DriverNumber_left  \
#  0  Mexican Grand Prix  2018  0 days 00:34:35.418000    GAS                 10
#  1  Mexican Grand Prix  2018  0 days 00:36:01.984000    GAS                 10
#  2  Mexican Grand Prix  2018  0 days 00:37:26.860000    GAS                 10
#  3  Mexican Grand Prix  2018  0 days 00:38:54.567000    GAS                 10
#  4  Mexican Grand Prix  2018  0 days 00:40:38.975000    GAS                 10
#
#                    LapTime  LapNumber  Stint PitOutTime  \
#  0  0 days 00:01:36.516000        1.0    1.0        NaN
#  1  0 days 00:01:26.566000        2.0    1.0        NaN
#  2  0 days 00:01:24.876000        3.0    1.0        NaN
#  3  0 days 00:01:27.707000        4.0    1.0        NaN
#  4  0 days 00:01:44.408000        5.0    1.0        NaN
#
#                  PitInTime  ... Time_left2 Status_right Points  \
#  0                     NaN  ...        NaN      +2 Laps    1.0
# ...

# %%
merged_data = pd.concat([all_data, race_all_data], ignore_index=True)

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23660 entries, 0 to 23659
# Data columns (total 92 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EventName           23660 non-null  object
#  1   Year                23660 non-null  int64
#  2   Time_x              23660 non-null  object
#  3   Driver              23660 non-null  object
#  4   DriverNumber_left   23660 non-null  int64
#  5   LapTime             23510 non-null  object
#  6   LapNumber           23660 non-null  float64
#  7   Stint               23660 non-null  float64
#  8   PitOutTime          697 non-null    object
#  9   PitInTime           706 non-null    object
#  10  Sector1Time         23199 non-null  object
#  11  Sector2Time         23634 non-null  object
#  12  Sector3Time         23610 non-null  object
#  13  Sector1SessionTime  23147 non-null  object
#  14  Sector2SessionTime  23634 non-null  object
# ...

# %%
# Save DataFrame to CSV
merged_data.to_csv('merged_data.csv', index=False)

# %%
# Save DataFrame to Excel
merged_data.to_excel('merged_data.xlsx', index=False)
